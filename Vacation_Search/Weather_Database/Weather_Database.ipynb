# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
#Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fort saint james
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | kavaratti
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | bilibino
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | hvammstangi
# City not found. Skipping...
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | torbay
# Processing Record 20 of Set 1 | yanai
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | beringovskiy
# Processing Record 23 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 1 | kruisfontein
# Processing Record 25 of Set 1 | rostovka
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | benjamin constant
# Processing Record 28 of Set 1 | saint-philippe
# Processing Record 29 of Set 1 | vestbygda
# City not found. Skipping...
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | saskylakh
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | ippy
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | leningradskiy
# Processing Record 36 of Set 1 | caravelas
# Processing Record 37 of Set 1 | ransang
# Processing Record 38 of Set 1 | narsaq
# Processing Record 39 of Set 1 | longyearbyen
# Processing Record 40 of Set 1 | tasiilaq
# Processing Record 41 of Set 1 | zamosc
# Processing Record 42 of Set 1 | cairns
# Processing Record 43 of Set 1 | kudahuvadhoo
# Processing Record 44 of Set 1 | vysokogornyy
# Processing Record 45 of Set 1 | cockburn town
# Processing Record 46 of Set 1 | shirvan
# Processing Record 47 of Set 1 | arraial do cabo
# Processing Record 48 of Set 1 | padang
# Processing Record 49 of Set 1 | korla
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 2 | dingle
# Processing Record 3 of Set 2 | oranjestad
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | egvekinot
# Processing Record 6 of Set 2 | punta gorda
# Processing Record 7 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 2 | nemuro
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | oistins
# Processing Record 11 of Set 2 | mayo
# Processing Record 12 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 2 | bambous virieux
# Processing Record 14 of Set 2 | paka
# Processing Record 15 of Set 2 | boa vista
# Processing Record 16 of Set 2 | dauphin
# Processing Record 17 of Set 2 | caraballeda
# Processing Record 18 of Set 2 | karoi
# Processing Record 19 of Set 2 | gold coast
# Processing Record 20 of Set 2 | vostok
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | saldanha
# Processing Record 23 of Set 2 | saurimo
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | lexington
# Processing Record 26 of Set 2 | brae
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | sunagawa
# Processing Record 29 of Set 2 | cherskiy
# Processing Record 30 of Set 2 | kasamwa
# Processing Record 31 of Set 2 | kuytun
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | kapaa
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | chifeng
# Processing Record 36 of Set 2 | dubenskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | oudtshoorn
# Processing Record 39 of Set 2 | yabrud
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | krasnovishersk
# Processing Record 42 of Set 2 | richards bay
# Processing Record 43 of Set 2 | tilichiki
# Processing Record 44 of Set 2 | antofagasta
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | orzhytsya
# Processing Record 48 of Set 2 | kawana waters
# City not found. Skipping...
# Processing Record 49 of Set 2 | meadow lake
# Processing Record 50 of Set 2 | puerto ayora
# Processing Record 1 of Set 3 | touros
# Processing Record 2 of Set 3 | shahr-e babak
# Processing Record 3 of Set 3 | hamilton
# Processing Record 4 of Set 3 | saint-pierre
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 3 | chuy
# Processing Record 8 of Set 3 | chokurdakh
# Processing Record 9 of Set 3 | airai
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | aksarka
# Processing Record 12 of Set 3 | sumkino
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | port macquarie
# Processing Record 15 of Set 3 | codrington
# Processing Record 16 of Set 3 | severo-kurilsk
# Processing Record 17 of Set 3 | poum
# Processing Record 18 of Set 3 | neuquen
# Processing Record 19 of Set 3 | lengshuijiang
# Processing Record 20 of Set 3 | chipata
# Processing Record 21 of Set 3 | izumo
# Processing Record 22 of Set 3 | bamberg
# Processing Record 23 of Set 3 | zakamensk
# Processing Record 24 of Set 3 | mega
# Processing Record 25 of Set 3 | awbari
# Processing Record 26 of Set 3 | pearland
# Processing Record 27 of Set 3 | astipalaia
# City not found. Skipping...
# Processing Record 28 of Set 3 | kilindoni
# Processing Record 29 of Set 3 | inirida
# Processing Record 30 of Set 3 | faanui
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | qaanaaq
# Processing Record 34 of Set 3 | san carlos
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | salinopolis
# Processing Record 37 of Set 3 | nikolskoye
# Processing Record 38 of Set 3 | te anau
# Processing Record 39 of Set 3 | lavrentiya
# Processing Record 40 of Set 3 | corn island
# Processing Record 41 of Set 3 | margate
# Processing Record 42 of Set 3 | aklavik
# Processing Record 43 of Set 3 | bethel
# Processing Record 44 of Set 3 | barbalha
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | kulaman
# Processing Record 47 of Set 3 | qena
# Processing Record 48 of Set 3 | pedernales
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | ilulissat
# Processing Record 1 of Set 4 | bonavista
# Processing Record 2 of Set 4 | zhanaozen
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | jamestown
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | cumra
# Processing Record 7 of Set 4 | kajaani
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | klaksvik
# Processing Record 10 of Set 4 | samarai
# Processing Record 11 of Set 4 | manakara
# Processing Record 12 of Set 4 | champerico
# Processing Record 13 of Set 4 | kiunga
# Processing Record 14 of Set 4 | upernavik
# Processing Record 15 of Set 4 | mar del plata
# Processing Record 16 of Set 4 | yerbogachen
# Processing Record 17 of Set 4 | mount isa
# Processing Record 18 of Set 4 | ulagan
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | elko
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | svetlogorsk
# Processing Record 23 of Set 4 | haines junction
# Processing Record 24 of Set 4 | sitka
# Processing Record 25 of Set 4 | zhigansk
# Processing Record 26 of Set 4 | san jeronimo
# Processing Record 27 of Set 4 | pemangkat
# Processing Record 28 of Set 4 | hanzhong
# Processing Record 29 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 4 | aksarayskiy
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | hutchinson
# Processing Record 33 of Set 4 | whangarei
# Processing Record 34 of Set 4 | husavik
# Processing Record 35 of Set 4 | coihaique
# Processing Record 36 of Set 4 | asfi
# Processing Record 37 of Set 4 | liloan
# Processing Record 38 of Set 4 | nouadhibou
# Processing Record 39 of Set 4 | bengkulu
# Processing Record 40 of Set 4 | danielskuil
# Processing Record 41 of Set 4 | menomonie
# Processing Record 42 of Set 4 | guerrero negro
# Processing Record 43 of Set 4 | zlatoust
# Processing Record 44 of Set 4 | kodiak
# Processing Record 45 of Set 4 | sur
# Processing Record 46 of Set 4 | kenai
# Processing Record 47 of Set 4 | qingdao
# Processing Record 48 of Set 4 | kununurra
# Processing Record 49 of Set 4 | cabedelo
# Processing Record 50 of Set 4 | atlantic city
# Processing Record 1 of Set 5 | manado
# Processing Record 2 of Set 5 | clyde river
# Processing Record 3 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 5 | puerto ayacucho
# Processing Record 5 of Set 5 | lagoa
# Processing Record 6 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 5 | nuuk
# Processing Record 8 of Set 5 | freeport
# Processing Record 9 of Set 5 | arman
# Processing Record 10 of Set 5 | alofi
# Processing Record 11 of Set 5 | cidreira
# Processing Record 12 of Set 5 | prince rupert
# Processing Record 13 of Set 5 | lorengau
# Processing Record 14 of Set 5 | tiznit
# Processing Record 15 of Set 5 | rolla
# Processing Record 16 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 17 of Set 5 | sioux lookout
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | bay roberts
# Processing Record 20 of Set 5 | dubbo
# Processing Record 21 of Set 5 | praia
# Processing Record 22 of Set 5 | shimoda
# Processing Record 23 of Set 5 | penha
# Processing Record 24 of Set 5 | visby
# Processing Record 25 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | saint george
# Processing Record 27 of Set 5 | henties bay
# Processing Record 28 of Set 5 | constitucion
# Processing Record 29 of Set 5 | tabas
# Processing Record 30 of Set 5 | praya
# Processing Record 31 of Set 5 | matara
# Processing Record 32 of Set 5 | tekeli
# Processing Record 33 of Set 5 | ballina
# Processing Record 34 of Set 5 | isangel
# Processing Record 35 of Set 5 | sao filipe
# Processing Record 36 of Set 5 | dezful
# Processing Record 37 of Set 5 | chapais
# Processing Record 38 of Set 5 | solnechnyy
# Processing Record 39 of Set 5 | humaita
# Processing Record 40 of Set 5 | talnakh
# Processing Record 41 of Set 5 | vila velha
# Processing Record 42 of Set 5 | iida
# Processing Record 43 of Set 5 | pahrump
# Processing Record 44 of Set 5 | tecoanapa
# Processing Record 45 of Set 5 | tieli
# Processing Record 46 of Set 5 | tazovskiy
# Processing Record 47 of Set 5 | shubarshi
# Processing Record 48 of Set 5 | sohag
# Processing Record 49 of Set 5 | ternate
# Processing Record 50 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 6 | zhezkazgan
# Processing Record 2 of Set 6 | cayenne
# Processing Record 3 of Set 6 | bageshwar
# Processing Record 4 of Set 6 | amberley
# Processing Record 5 of Set 6 | souillac
# Processing Record 6 of Set 6 | mao
# Processing Record 7 of Set 6 | mindelo
# Processing Record 8 of Set 6 | grand gaube
# Processing Record 9 of Set 6 | luderitz
# Processing Record 10 of Set 6 | lompoc
# Processing Record 11 of Set 6 | gizo
# Processing Record 12 of Set 6 | senador guiomard
# Processing Record 13 of Set 6 | puerto madryn
# Processing Record 14 of Set 6 | broken hill
# Processing Record 15 of Set 6 | dhidhdhoo
# Processing Record 16 of Set 6 | tongliao
# Processing Record 17 of Set 6 | iqaluit
# Processing Record 18 of Set 6 | lake havasu city
# Processing Record 19 of Set 6 | manaure
# Processing Record 20 of Set 6 | portland
# Processing Record 21 of Set 6 | finnsnes
# Processing Record 22 of Set 6 | gao
# Processing Record 23 of Set 6 | preobrazheniye
# Processing Record 24 of Set 6 | san cristobal
# Processing Record 25 of Set 6 | lastoursville
# Processing Record 26 of Set 6 | mandalgovi
# Processing Record 27 of Set 6 | alice springs
# Processing Record 28 of Set 6 | zyryanovskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | tekirdag
# Processing Record 30 of Set 6 | huarmey
# Processing Record 31 of Set 6 | bara
# Processing Record 32 of Set 6 | lasa
# Processing Record 33 of Set 6 | payakumbuh
# Processing Record 34 of Set 6 | laguna
# Processing Record 35 of Set 6 | salalah
# Processing Record 36 of Set 6 | pacific grove
# Processing Record 37 of Set 6 | gari
# Processing Record 38 of Set 6 | saravan
# Processing Record 39 of Set 6 | chino valley
# Processing Record 40 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 6 | sabang
# Processing Record 42 of Set 6 | bo rai
# Processing Record 43 of Set 6 | kristiinankaupunki
# Processing Record 44 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 45 of Set 6 | kieta
# Processing Record 46 of Set 6 | trelew
# Processing Record 47 of Set 6 | san patricio
# Processing Record 48 of Set 6 | lishu
# Processing Record 49 of Set 6 | vuktyl
# Processing Record 50 of Set 6 | anan
# Processing Record 1 of Set 7 | miyako
# Processing Record 2 of Set 7 | tres picos
# Processing Record 3 of Set 7 | puerto leguizamo
# Processing Record 4 of Set 7 | chumikan
# Processing Record 5 of Set 7 | nogliki
# Processing Record 6 of Set 7 | kuito
# Processing Record 7 of Set 7 | maur
# Processing Record 8 of Set 7 | bridlington
# Processing Record 9 of Set 7 | port lincoln
# Processing Record 10 of Set 7 | sambava
# Processing Record 11 of Set 7 | nioki
# Processing Record 12 of Set 7 | novoagansk
# Processing Record 13 of Set 7 | sopotnica
# Processing Record 14 of Set 7 | toora-khem
# Processing Record 15 of Set 7 | shu
# Processing Record 16 of Set 7 | stramtura
# Processing Record 17 of Set 7 | hinton
# Processing Record 18 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 7 | nalut
# Processing Record 20 of Set 7 | reggio di calabria
# Processing Record 21 of Set 7 | irbeyskoye
# Processing Record 22 of Set 7 | geraldton
# Processing Record 23 of Set 7 | hobyo
# Processing Record 24 of Set 7 | sabana grande de boya
# Processing Record 25 of Set 7 | kaitangata
# Processing Record 26 of Set 7 | okhotsk
# Processing Record 27 of Set 7 | kerman
# Processing Record 28 of Set 7 | ahipara
# Processing Record 29 of Set 7 | ilanskiy
# Processing Record 30 of Set 7 | hasaki
# Processing Record 31 of Set 7 | katsuura
# Processing Record 32 of Set 7 | puerto del rosario
# Processing Record 33 of Set 7 | quelimane
# Processing Record 34 of Set 7 | launceston
# Processing Record 35 of Set 7 | barguzin
# Processing Record 36 of Set 7 | wewak
# Processing Record 37 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 7 | qarqin
# Processing Record 39 of Set 7 | mayumba
# Processing Record 40 of Set 7 | san carlos de bariloche
# Processing Record 41 of Set 7 | rocha
# Processing Record 42 of Set 7 | san pedro
# Processing Record 43 of Set 7 | martapura
# Processing Record 44 of Set 7 | hisar
# Processing Record 45 of Set 7 | kavieng
# Processing Record 46 of Set 7 | picui
# Processing Record 47 of Set 7 | yurty
# Processing Record 48 of Set 7 | miandoab
# Processing Record 49 of Set 7 | cozumel
# Processing Record 50 of Set 7 | teguise
# Processing Record 1 of Set 8 | naze
# Processing Record 2 of Set 8 | alexandria
# Processing Record 3 of Set 8 | urumqi
# Processing Record 4 of Set 8 | ancud
# Processing Record 5 of Set 8 | provideniya
# Processing Record 6 of Set 8 | nome
# Processing Record 7 of Set 8 | campbell river
# Processing Record 8 of Set 8 | sinegorye
# Processing Record 9 of Set 8 | kargasok
# Processing Record 10 of Set 8 | harper
# Processing Record 11 of Set 8 | srednekolymsk
# Processing Record 12 of Set 8 | beruwala
# Processing Record 13 of Set 8 | cabatuan
# Processing Record 14 of Set 8 | bassano
# Processing Record 15 of Set 8 | kawalu
# Processing Record 16 of Set 8 | ngaoundere
# Processing Record 17 of Set 8 | santa isabel do rio negro
# Processing Record 18 of Set 8 | fort dodge
# Processing Record 19 of Set 8 | nehe
# Processing Record 20 of Set 8 | fare
# Processing Record 21 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 22 of Set 8 | camocim
# Processing Record 23 of Set 8 | aswan
# Processing Record 24 of Set 8 | rodez
# Processing Record 25 of Set 8 | mangan
# Processing Record 26 of Set 8 | flinders
# Processing Record 27 of Set 8 | kamenka
# Processing Record 28 of Set 8 | lumphat
# Processing Record 29 of Set 8 | palmer
# Processing Record 30 of Set 8 | fairbanks
# Processing Record 31 of Set 8 | beibei
# Processing Record 32 of Set 8 | yar-sale
# Processing Record 33 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 8 | nanortalik
# Processing Record 35 of Set 8 | chake chake
# Processing Record 36 of Set 8 | nyborg
# Processing Record 37 of Set 8 | houston
# Processing Record 38 of Set 8 | nisia floresta
# Processing Record 39 of Set 8 | petropavlovka
# Processing Record 40 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 41 of Set 8 | greeneville
# Processing Record 42 of Set 8 | morehead
# Processing Record 43 of Set 8 | antalaha
# Processing Record 44 of Set 8 | mezen
# Processing Record 45 of Set 8 | seljord
# Processing Record 46 of Set 8 | ambilobe
# Processing Record 47 of Set 8 | cochrane
# Processing Record 48 of Set 8 | bandarbeyla
# Processing Record 49 of Set 8 | tashigang
# Processing Record 50 of Set 8 | tailai
# Processing Record 1 of Set 9 | redmond
# Processing Record 2 of Set 9 | naranjito
# Processing Record 3 of Set 9 | nicolas bravo
# Processing Record 4 of Set 9 | kloulklubed
# Processing Record 5 of Set 9 | kashi
# Processing Record 6 of Set 9 | el dorado
# Processing Record 7 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 9 | sisimiut
# Processing Record 9 of Set 9 | grindavik
# Processing Record 10 of Set 9 | taltal
# Processing Record 11 of Set 9 | mandera
# Processing Record 12 of Set 9 | visnes
# Processing Record 13 of Set 9 | presidencia roque saenz pena
# Processing Record 14 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 9 | chabahar
# Processing Record 16 of Set 9 | bubaque
# Processing Record 17 of Set 9 | marzuq
# Processing Record 18 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 9 | watertown
# Processing Record 20 of Set 9 | mokhsogollokh
# Processing Record 21 of Set 9 | kantang
# Processing Record 22 of Set 9 | bereda
# Processing Record 23 of Set 9 | bonthe
# Processing Record 24 of Set 9 | alvorada
# Processing Record 25 of Set 9 | camp verde
# Processing Record 26 of Set 9 | the pas
# Processing Record 27 of Set 9 | palora
# Processing Record 28 of Set 9 | bulaevo
# Processing Record 29 of Set 9 | inuvik
# Processing Record 30 of Set 9 | tongren
# Processing Record 31 of Set 9 | tuatapere
# Processing Record 32 of Set 9 | eboli
# Processing Record 33 of Set 9 | morondava
# Processing Record 34 of Set 9 | lobito
# Processing Record 35 of Set 9 | fria
# Processing Record 36 of Set 9 | opuwo
# Processing Record 37 of Set 9 | faya
# Processing Record 38 of Set 9 | lata
# Processing Record 39 of Set 9 | burica
# City not found. Skipping...
# Processing Record 40 of Set 9 | ixtapa
# Processing Record 41 of Set 9 | kuala terengganu
# Processing Record 42 of Set 9 | trairi
# Processing Record 43 of Set 9 | el alto
# Processing Record 44 of Set 9 | amalapuram
# Processing Record 45 of Set 9 | rosarito
# Processing Record 46 of Set 9 | esperance
# Processing Record 47 of Set 9 | thinadhoo
# Processing Record 48 of Set 9 | itaituba
# Processing Record 49 of Set 9 | ekhabi
# Processing Record 50 of Set 9 | vondrozo
# Processing Record 1 of Set 10 | tamandare
# Processing Record 2 of Set 10 | batagay-alyta
# Processing Record 3 of Set 10 | reading
# Processing Record 4 of Set 10 | ca mau
# Processing Record 5 of Set 10 | port hedland
# Processing Record 6 of Set 10 | carlyle
# Processing Record 7 of Set 10 | romny
# Processing Record 8 of Set 10 | nepomuk
# Processing Record 9 of Set 10 | tabou
# Processing Record 10 of Set 10 | coquimbo
# Processing Record 11 of Set 10 | tautira
# Processing Record 12 of Set 10 | bridgetown
# Processing Record 13 of Set 10 | linqiong
# Processing Record 14 of Set 10 | vredendal
# Processing Record 15 of Set 10 | komsomolskiy
# Processing Record 16 of Set 10 | tonantins
# Processing Record 17 of Set 10 | saint anthony
# Processing Record 18 of Set 10 | valdivia
# Processing Record 19 of Set 10 | bobrovka
# Processing Record 20 of Set 10 | tessalit
# Processing Record 21 of Set 10 | amarpatan
# Processing Record 22 of Set 10 | hofn
# Processing Record 23 of Set 10 | nizhniy kuranakh
# Processing Record 24 of Set 10 | olafsvik
# Processing Record 25 of Set 10 | les cayes
# Processing Record 26 of Set 10 | hovd
# Processing Record 27 of Set 10 | verkhnevilyuysk
# Processing Record 28 of Set 10 | moreira sales
# Processing Record 29 of Set 10 | bor
# Processing Record 30 of Set 10 | kinkala
# Processing Record 31 of Set 10 | pauini
# Processing Record 32 of Set 10 | aleksandrovsk
# Processing Record 33 of Set 10 | paoua
# Processing Record 34 of Set 10 | tsaratanana
# Processing Record 35 of Set 10 | karratha
# Processing Record 36 of Set 10 | guanare
# Processing Record 37 of Set 10 | dali
# Processing Record 38 of Set 10 | smithers
# Processing Record 39 of Set 10 | mandan
# Processing Record 40 of Set 10 | novotroitskaya
# Processing Record 41 of Set 10 | esso
# Processing Record 42 of Set 10 | vrangel
# Processing Record 43 of Set 10 | san vicente
# Processing Record 44 of Set 10 | nyagan
# Processing Record 45 of Set 10 | hambantota
# Processing Record 46 of Set 10 | markova
# Processing Record 47 of Set 10 | qaqortoq
# Processing Record 48 of Set 10 | russell
# Processing Record 49 of Set 10 | clermont
# Processing Record 50 of Set 10 | bathsheba
# Processing Record 1 of Set 11 | bani
# Processing Record 2 of Set 11 | vestmannaeyjar
# Processing Record 3 of Set 11 | namatanai
# Processing Record 4 of Set 11 | quatre cocos
# Processing Record 5 of Set 11 | topolobampo
# Processing Record 6 of Set 11 | fort-shevchenko
# Processing Record 7 of Set 11 | araouane
# Processing Record 8 of Set 11 | sinnamary
# Processing Record 9 of Set 11 | norman wells
# Processing Record 10 of Set 11 | barra patuca
# Processing Record 11 of Set 11 | palana
# Processing Record 12 of Set 11 | ostrovnoy
# Processing Record 13 of Set 11 | boone
# Processing Record 14 of Set 11 | tandil
# Processing Record 15 of Set 11 | xiaoweizhai
# Processing Record 16 of Set 11 | bacolod
# Processing Record 17 of Set 11 | kosonsoy
# Processing Record 18 of Set 11 | albanel
# Processing Record 19 of Set 11 | tarana
# Processing Record 20 of Set 11 | joensuu
# Processing Record 21 of Set 11 | aden
# Processing Record 22 of Set 11 | cartagena
# Processing Record 23 of Set 11 | shelburne
# Processing Record 24 of Set 11 | tateyama
# Processing Record 25 of Set 11 | vardo
# Processing Record 26 of Set 11 | salvador
# Processing Record 27 of Set 11 | boyle
# Processing Record 28 of Set 11 | puerto madero
# Processing Record 29 of Set 11 | simbahan
# Processing Record 30 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 11 | bardiyah
# Processing Record 33 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 11 | kazachinskoye
# Processing Record 35 of Set 11 | san jose
# Processing Record 36 of Set 11 | xining
# Processing Record 37 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 11 | guekedou
# City not found. Skipping...
# Processing Record 39 of Set 11 | eyl
# Processing Record 40 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 11 | pocoes
# Processing Record 42 of Set 11 | ahuimanu
# Processing Record 43 of Set 11 | tangshan
# Processing Record 44 of Set 11 | port-gentil
# Processing Record 45 of Set 11 | kahului
# Processing Record 46 of Set 11 | gravdal
# Processing Record 47 of Set 11 | havelock
# Processing Record 48 of Set 11 | gushikawa
# Processing Record 49 of Set 11 | sao joao da barra
# Processing Record 50 of Set 11 | maxixe
# Processing Record 1 of Set 12 | scarborough
# Processing Record 2 of Set 12 | tarangnan
# Processing Record 3 of Set 12 | rio grande
# Processing Record 4 of Set 12 | chardara
# Processing Record 5 of Set 12 | severo-yeniseyskiy
# Processing Record 6 of Set 12 | roald
# Processing Record 7 of Set 12 | cap malheureux
# Processing Record 8 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 12 | kutiyana
# Processing Record 10 of Set 12 | deputatskiy
# Processing Record 11 of Set 12 | comodoro rivadavia
# Processing Record 12 of Set 12 | berlevag
# Processing Record 13 of Set 12 | pisco
# Processing Record 14 of Set 12 | noumea
# Processing Record 15 of Set 12 | ranong
# Processing Record 16 of Set 12 | unye
# City not found. Skipping...
# Processing Record 17 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 12 | iskateley
# Processing Record 19 of Set 12 | vestmanna
# Processing Record 20 of Set 12 | estrela
# Processing Record 21 of Set 12 | antigonish
# Processing Record 22 of Set 12 | altay
# Processing Record 23 of Set 12 | novoseleznevo
# Processing Record 24 of Set 12 | corrente
# Processing Record 25 of Set 12 | dumas
# Processing Record 26 of Set 12 | paamiut
# Processing Record 27 of Set 12 | mount gambier
# Processing Record 28 of Set 12 | qui nhon
# Processing Record 29 of Set 12 | northam
# Processing Record 30 of Set 12 | teya
# Processing Record 31 of Set 12 | san quintin
# Processing Record 32 of Set 12 | vana-voidu
# City not found. Skipping...
# Processing Record 33 of Set 12 | qandala
# Processing Record 34 of Set 12 | sault sainte marie
# Processing Record 35 of Set 12 | lunenburg
# Processing Record 36 of Set 12 | hirara
# Processing Record 37 of Set 12 | krasnoselkup
# Processing Record 38 of Set 12 | iwata
# Processing Record 39 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 12 | antiguo morelos
# Processing Record 41 of Set 12 | satipo
# Processing Record 42 of Set 12 | kolpashevo
# Processing Record 43 of Set 12 | bria
# Processing Record 44 of Set 12 | west bay
# Processing Record 45 of Set 12 | landerneau
# Processing Record 46 of Set 12 | arlit
# Processing Record 47 of Set 12 | owensboro
# Processing Record 48 of Set 12 | maketu
# Processing Record 49 of Set 12 | caohai
# Processing Record 50 of Set 12 | unai
# Processing Record 1 of Set 13 | mackay
# Processing Record 2 of Set 13 | karibib
# Processing Record 3 of Set 13 | lindau
# Processing Record 4 of Set 13 | guzelyurt
# Processing Record 5 of Set 13 | santiago
# Processing Record 6 of Set 13 | ejido
# Processing Record 7 of Set 13 | raudeberg
# Processing Record 8 of Set 13 | flin flon
# Processing Record 9 of Set 13 | praia da vitoria
# Processing Record 10 of Set 13 | kalaleh
# Processing Record 11 of Set 13 | puro
# Processing Record 12 of Set 13 | shishou
# Processing Record 13 of Set 13 | howell
# Processing Record 14 of Set 13 | saint-georges
# Processing Record 15 of Set 13 | kota belud
# Processing Record 16 of Set 13 | darhan
# Processing Record 17 of Set 13 | ranot
# Processing Record 18 of Set 13 | solwezi
# Processing Record 19 of Set 13 | kuryk
# Processing Record 20 of Set 13 | north myrtle beach
# Processing Record 21 of Set 13 | waterloo
# Processing Record 22 of Set 13 | pochutla
# Processing Record 23 of Set 13 | porto seguro
# Processing Record 24 of Set 13 | tupiza
# Processing Record 25 of Set 13 | itarema
# Processing Record 26 of Set 13 | waingapu
# Processing Record 27 of Set 13 | ayan
# Processing Record 28 of Set 13 | quba
# Processing Record 29 of Set 13 | ismailia
# Processing Record 30 of Set 13 | kosa
# Processing Record 31 of Set 13 | lincoln
# Processing Record 32 of Set 13 | waiouru
# Processing Record 33 of Set 13 | envira
# Processing Record 34 of Set 13 | khandyga
# Processing Record 35 of Set 13 | fershampenuaz
# Processing Record 36 of Set 13 | yulara
# Processing Record 37 of Set 13 | sao felix do xingu
# Processing Record 38 of Set 13 | lawrenceburg
# Processing Record 39 of Set 13 | vallenar
# Processing Record 40 of Set 13 | baishishan
# Processing Record 41 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 13 | boguchany
# Processing Record 43 of Set 13 | dudinka
# Processing Record 44 of Set 13 | cururupu
# Processing Record 45 of Set 13 | libreville
# Processing Record 46 of Set 13 | roebourne
# Processing Record 47 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 13 | svetlaya
# Processing Record 49 of Set 13 | marsh harbour
# Processing Record 50 of Set 13 | key west
# Processing Record 1 of Set 14 | moranbah
# Processing Record 2 of Set 14 | yate
# Processing Record 3 of Set 14 | sokoni
# Processing Record 4 of Set 14 | machacamarca
# Processing Record 5 of Set 14 | kaeo
# Processing Record 6 of Set 14 | joinville
# Processing Record 7 of Set 14 | porto novo
# Processing Record 8 of Set 14 | conde
# Processing Record 9 of Set 14 | ishigaki
# Processing Record 10 of Set 14 | kapit
# Processing Record 11 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 12 of Set 14 | asau
# Processing Record 13 of Set 14 | besikduzu
# Processing Record 14 of Set 14 | manta
# Processing Record 15 of Set 14 | mana
# Processing Record 16 of Set 14 | camabatela
# Processing Record 17 of Set 14 | omsukchan
# Processing Record 18 of Set 14 | cherepovets
# Processing Record 19 of Set 14 | goderich
# Processing Record 20 of Set 14 | port pirie
# Processing Record 21 of Set 14 | vilyuysk
# Processing Record 22 of Set 14 | narasannapeta
# Processing Record 23 of Set 14 | sakaiminato
# Processing Record 24 of Set 14 | meulaboh
# Processing Record 25 of Set 14 | ankara
# Processing Record 26 of Set 14 | manokwari
# Processing Record 27 of Set 14 | puerto quijarro
# Processing Record 28 of Set 14 | port keats
# Processing Record 29 of Set 14 | yeppoon
# Processing Record 30 of Set 14 | zalantun
# Processing Record 31 of Set 14 | safaga
# Processing Record 32 of Set 14 | namibe
# Processing Record 33 of Set 14 | sam chuk
# Processing Record 34 of Set 14 | mehamn
# Processing Record 35 of Set 14 | iranshahr
# Processing Record 36 of Set 14 | ilawe
# Processing Record 37 of Set 14 | bagotville
# Processing Record 38 of Set 14 | mamlyutka
# Processing Record 39 of Set 14 | hualmay
# Processing Record 40 of Set 14 | acarau
# Processing Record 41 of Set 14 | mahon
# Processing Record 42 of Set 14 | devils lake
# Processing Record 43 of Set 14 | sarahan
# Processing Record 44 of Set 14 | mogadishu
# Processing Record 45 of Set 14 | lapua
# Processing Record 46 of Set 14 | half moon bay
# Processing Record 47 of Set 14 | kragero
# Processing Record 48 of Set 14 | manono
# Processing Record 49 of Set 14 | okato
# Processing Record 50 of Set 14 | inhambane
# Processing Record 1 of Set 15 | moose factory
# Processing Record 2 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 15 | pop
# Processing Record 4 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 15 | kadnikov
# Processing Record 6 of Set 15 | jiangkou
# Processing Record 7 of Set 15 | xifeng
# Processing Record 8 of Set 15 | sovetskiy
# Processing Record 9 of Set 15 | los andes
# Processing Record 10 of Set 15 | berdigestyakh
# Processing Record 11 of Set 15 | longonjo
# Processing Record 12 of Set 15 | acapulco
# Processing Record 13 of Set 15 | kusti
# Processing Record 14 of Set 15 | fort nelson
# Processing Record 15 of Set 15 | huzhou
# Processing Record 16 of Set 15 | esil
# Processing Record 17 of Set 15 | jandaia do sul
# Processing Record 18 of Set 15 | floro
# Processing Record 19 of Set 15 | beloha
# Processing Record 20 of Set 15 | hit
# Processing Record 21 of Set 15 | sanmenxia
# Processing Record 22 of Set 15 | chakwal
# Processing Record 23 of Set 15 | surskoye
# Processing Record 24 of Set 15 | soria
# Processing Record 25 of Set 15 | irtyshskiy
# Processing Record 26 of Set 15 | megion
# Processing Record 27 of Set 15 | salinas
# Processing Record 28 of Set 15 | abu dhabi
# Processing Record 29 of Set 15 | qabis
# City not found. Skipping...
# Processing Record 30 of Set 15 | takoradi
# Processing Record 31 of Set 15 | sharlyk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Fort Saint James  54.4333 -124.2500     29.10        95         100
# 1       Tuktoyaktuk  69.4541 -133.0374     -4.00        77          90
# 2       New Norfolk -42.7826  147.0587     50.00        66          25
# 3            Atuona  -9.8000 -139.0333     77.45        77           1
# 4         Kavaratti  10.5669   72.6420     82.27        77          10
# 5       East London -33.0153   27.9116     69.80        68           0
# 6           Mataura -46.1927  168.8643     63.00        85         100
# 7      Punta Arenas -53.1500  -70.9167     60.80        59          90
# 8       Yellowknife  62.4560 -114.3525     -0.40        78          90
# 9          Bilibino  68.0546  166.4372    -16.33        85         100
#
#    Wind Speed Country Current Description
# 0        2.46      CA     overcast clouds
# 1       11.50      CA          light snow
# 2        3.00      AU    scattered clouds
# 3       13.27      PF           clear sky
# 4        9.42      IN           clear sky
# 5       27.63      ZA           clear sky
# 6        3.00      NZ     overcast clouds
# 7       14.97      CL     overcast clouds
# 8        8.05      CA          light snow
# 9        0.63      RU     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
new_column_order
# Out:
# ['City',
#  'Country',
#  'Lat',
#  'Lng',
#  'Max Temp',
#  'Humidity',
#  'Cloudiness',
#  'Wind Speed',
#  'Current Description']

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Fort Saint James      CA  54.4333 -124.2500     29.10        95
# 1         Tuktoyaktuk      CA  69.4541 -133.0374     -4.00        77
# 2         New Norfolk      AU -42.7826  147.0587     50.00        66
# 3              Atuona      PF  -9.8000 -139.0333     77.45        77
# 4           Kavaratti      IN  10.5669   72.6420     82.27        77
# ..                ...     ...      ...       ...       ...       ...
# 677            Megion      RU  61.0296   76.1136      3.20        85
# 678           Salinas      US  36.6777 -121.6555     54.00        76
# 679         Abu Dhabi      AE  24.4667   54.3667     68.00        68
# 680          Takoradi      GH   4.8845   -1.7554     85.55        66
# 681           Sharlyk      RU  52.9167   54.7500     12.11        95
#
#      Cloudiness  Wind Speed Current Description
# 0           100        2.46     overcast clouds
# 1            90       11.50          light snow
# 2            25        3.00    scattered clouds
# 3             1       13.27           clear sky
# 4            10        9.42           clear sky
# ..          ...         ...                 ...
# 677           0        4.47           clear sky
# 678           1        3.44           clear sky
# 679           0        5.75           clear sky
# 680          82        7.05          light rain
# 681         100       11.65     overcast clouds
#
# [682 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# %%
city_data_df.to_csv(output_data_file, index_label="City_ID")
